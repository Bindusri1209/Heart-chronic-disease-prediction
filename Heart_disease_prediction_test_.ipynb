# %%
import keras   #Imports

# %%
from keras.models import Sequential
obj = Sequential()   #Model Creation

# %%
from keras.layers import Dense

# %%
import pandas as pd

dt = pd.read_csv('/content/heart.csv')   #Data Loading
dt.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
dt.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# target   -0.229324 -0.279501  0.434854 -0.138772 -0.099966 -0.041164
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.132696 -0.390227  0.088163  0.208137 -0.169105  0.271551
# sex      -0.055117 -0.049365  0.139157  0.084687 -0.026666  0.111729
# cp        0.043581  0.306839 -0.401513 -0.174733  0.131633 -0.176206
# trestbps -0.123794 -0.039264  0.061197  0.187434 -0.120445  0.104554
# chol     -0.147410 -0.021772  0.067382  0.064880 -0.014248  0.074259
# fbs      -0.104051 -0.008866  0.049261  0.010859 -0.061902  0.137156
# restecg   1.000000  0.048411 -0.065606 -0.050114  0.086086 -0.078072
# thalach   0.048411  1.000000 -0.380281 -0.349796  0.395308 -0.207888
# exang    -0.065606 -0.380281  1.000000  0.310844 -0.267335  0.107849
# oldpeak  -0.050114 -0.349796  0.310844  1.000000 -0.575189  0.221816
# slope     0.086086  0.395308 -0.267335 -0.575189  1.000000 -0.073440
# ca       -0.078072 -0.207888  0.107849  0.221816 -0.073440  1.000000
# thal     -0.020504 -0.098068  0.197201  0.202672 -0.094090  0.149014
# target    0.134468  0.422895 -0.438029 -0.438441  0.345512 -0.382085
#
#               thal    target
# age       0.072297 -0.229324
# sex       0.198424 -0.279501
# cp       -0.163341  0.434854
# trestbps  0.059276 -0.138772
# chol      0.100244 -0.099966
# fbs      -0.042177 -0.041164
# restecg  -0.020504  0.134468
# thalach  -0.098068  0.422895
# exang     0.197201 -0.438029
# oldpeak   0.202672 -0.438441
# slope    -0.094090  0.345512
# ca        0.149014 -0.382085
# thal      1.000000 -0.337838
# target   -0.337838  1.000000

# %%
dt = dt.drop(['chol','fbs'],axis=1)

# %%
dt.tail(1)
# Out:
#       age  sex  cp  trestbps  restecg  thalach  exang  oldpeak  slope  ca  \
# 1024   54    1   0       120        1      113      0      1.4      1   1
#
#       thal  target
# 1024     3       0

# %%
x = dt.iloc[:,0:11]   #Feature Selection
y = dt['target']

# %%
x
# Out:
#       age  sex  cp  trestbps  restecg  thalach  exang  oldpeak  slope  ca  \
# 0      52    1   0       125        1      168      0      1.0      2   2
# 1      53    1   0       140        0      155      1      3.1      0   0
# 2      70    1   0       145        1      125      1      2.6      0   0
# 3      61    1   0       148        1      161      0      0.0      2   1
# 4      62    0   0       138        1      106      0      1.9      1   3
# ...   ...  ...  ..       ...      ...      ...    ...      ...    ...  ..
# 1020   59    1   1       140        1      164      1      0.0      2   0
# 1021   60    1   0       125        0      141      1      2.8      1   1
# 1022   47    1   0       110        0      118      1      1.0      1   1
# 1023   50    0   0       110        0      159      0      0.0      2   0
# 1024   54    1   0       120        1      113      0      1.4      1   1
#
#       thal
# 0        3
# 1        3
# 2        3
# 3        3
# 4        2
# ...    ...
# 1020     2
# 1021     3
# 1022     2
# 1023     2
# 1024     3
#
# [1025 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split   #Data Split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)

# %%
print(x.shape,y.shape,x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (1025, 11) (1025,) (768, 11) (257, 11) (768,) (257,)

# %%
obj.add(Dense(units=11,activation='relu'))  #Model Architecture

# %%
obj.add(Dense(units=5,activation='relu'))

# %%
obj.add(Dense(units=1,activation='sigmoid'))

# %%
obj.build(input_shape=(None,11))

# %%
obj.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 198 (792.00 B)
#  Trainable params: 198 (792.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
obj.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
obj.fit(x_train,y_train,epochs=100,batch_size=8,steps_per_epoch=x_train.shape[0]//8)
# Out:
# Epoch 1/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6041 - loss: 2.8134
# Epoch 2/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6800 - loss: 0.5736
# Epoch 3/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6779 - loss: 0.5901
# Epoch 4/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6945 - loss: 0.5296
# Epoch 5/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6874 - loss: 0.5250
# Epoch 6/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7011 - loss: 0.5593
# Epoch 7/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7105 - loss: 0.5178
# Epoch 8/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7327 - loss: 0.5065
# Epoch 9/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7421 - loss: 0.5181
# Epoch 10/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7558 - loss: 0.5072
# Epoch 11/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7676 - loss: 0.4975
# Epoch 12/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7837 - loss: 0.4907
# Epoch 13/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7461 - loss: 0.5778
# Epoch 14/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7597 - loss: 0.5423
# Epoch 15/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7604 - loss: 0.5532
# Epoch 16/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7998 - loss: 0.5141
# Epoch 17/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7922 - loss: 0.5230
# Epoch 18/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8050 - loss: 0.4836
# Epoch 19/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8022 - loss: 0.4912
# Epoch 20/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8147 - loss: 0.4614
# Epoch 21/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8017 - loss: 0.4885
# Epoch 22/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8175 - loss: 0.4644
# Epoch 23/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8431 - loss: 0.4509
# Epoch 24/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7912 - loss: 0.4670
# Epoch 25/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8199 - loss: 0.4669
# Epoch 26/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8248 - loss: 0.4495
# Epoch 27/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8301 - loss: 0.4415
# Epoch 28/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8530 - loss: 0.4191
# Epoch 29/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8205 - loss: 0.4306
# Epoch 30/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7644 - loss: 0.4855
# Epoch 31/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8402 - loss: 0.4239
# Epoch 32/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8349 - loss: 0.4062
# Epoch 33/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8321 - loss: 0.4302
# Epoch 34/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8299 - loss: 0.4246
# Epoch 35/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8433 - loss: 0.4191
# Epoch 36/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8338 - loss: 0.4307
# Epoch 37/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8284 - loss: 0.4161
# Epoch 38/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7903 - loss: 0.4159
# Epoch 39/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8113 - loss: 0.4168
# Epoch 40/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8386 - loss: 0.3732
# Epoch 41/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8173 - loss: 0.4346
# Epoch 42/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8044 - loss: 0.4202
# Epoch 43/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8111 - loss: 0.4366
# Epoch 44/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8414 - loss: 0.3915
# Epoch 45/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8459 - loss: 0.3933
# Epoch 46/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8211 - loss: 0.4201
# Epoch 47/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8257 - loss: 0.4251
# Epoch 48/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8376 - loss: 0.3793
# Epoch 49/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8339 - loss: 0.3900
# Epoch 50/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8191 - loss: 0.4131
# Epoch 51/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8414 - loss: 0.3766
# Epoch 52/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8253 - loss: 0.4111
# Epoch 53/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8339 - loss: 0.3943
# Epoch 54/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7991 - loss: 0.4463
# Epoch 55/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8234 - loss: 0.4219
# Epoch 56/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8307 - loss: 0.3943
# Epoch 57/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8381 - loss: 0.3934
# Epoch 58/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8094 - loss: 0.4314
# Epoch 59/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8588 - loss: 0.3869
# Epoch 60/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8316 - loss: 0.4080
# Epoch 61/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8412 - loss: 0.3818
# Epoch 62/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8419 - loss: 0.3765
# Epoch 63/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8525 - loss: 0.3826
# Epoch 64/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8542 - loss: 0.3721
# Epoch 65/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8090 - loss: 0.4109
# Epoch 66/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8408 - loss: 0.3919
# Epoch 67/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8686 - loss: 0.3524
# Epoch 68/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8428 - loss: 0.3807
# Epoch 69/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8483 - loss: 0.3657
# Epoch 70/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8349 - loss: 0.4071
# Epoch 71/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8378 - loss: 0.3855
# Epoch 72/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8333 - loss: 0.3837
# Epoch 73/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8278 - loss: 0.4011
# Epoch 74/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8323 - loss: 0.3964
# Epoch 75/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8394 - loss: 0.4024
# Epoch 76/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8158 - loss: 0.4149
# Epoch 77/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8224 - loss: 0.4100
# Epoch 78/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8480 - loss: 0.3725
# Epoch 79/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8155 - loss: 0.4285
# Epoch 80/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8327 - loss: 0.3893
# Epoch 81/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8398 - loss: 0.3842
# Epoch 82/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8470 - loss: 0.4026
# Epoch 83/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8425 - loss: 0.3810
# Epoch 84/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8571 - loss: 0.3796
# Epoch 85/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8446 - loss: 0.3904
# Epoch 86/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8585 - loss: 0.3601
# Epoch 87/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8200 - loss: 0.3879
# Epoch 88/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8525 - loss: 0.3792
# Epoch 89/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8541 - loss: 0.3887
# Epoch 90/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8537 - loss: 0.3515
# Epoch 91/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8535 - loss: 0.3469
# Epoch 92/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8365 - loss: 0.3694
# Epoch 93/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8419 - loss: 0.3686
# Epoch 94/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8285 - loss: 0.3933
# Epoch 95/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8507 - loss: 0.3545
# Epoch 96/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8231 - loss: 0.4022
# Epoch 97/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8437 - loss: 0.3768
# Epoch 98/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8360 - loss: 0.3848
# Epoch 99/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8358 - loss: 0.3871
# Epoch 100/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8625 - loss: 0.3641

# %%
y_pred = obj.predict(x_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
y_pred = (y_pred > 0.5).astype(int)

# %%
from sklearn.metrics import accuracy_score  #Evaluation
accuracy_score(y_test,y_pred)
# Out:
# 0.8715953307392996

# %%
obj.save('heart.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
x_train
# Out:
#      age  sex  cp  trestbps  restecg  thalach  exang  oldpeak  slope  ca  thal
# 906   42    1   0       140        1      178      0      0.0      2   0     2
# 176   56    1   0       130        0      103      1      1.6      0   0     3
# 12    34    0   1       118        1      192      0      0.7      2   0     2
# 538   46    1   0       120        0      144      0      0.8      2   0     3
# 871   39    1   2       140        0      182      0      0.0      2   0     2
# ..   ...  ...  ..       ...      ...      ...    ...      ...    ...  ..   ...
# 593   63    0   0       108        1      169      1      1.8      1   2     2
# 227   44    0   2       118        1      149      0      0.3      1   1     2
# 740   44    1   2       140        0      180      0      0.0      2   0     2
# 34    50    1   2       129        1      163      0      0.0      2   0     2
# 489   61    1   2       150        1      137      1      1.0      1   0     2
#
# [768 rows x 11 columns]

# %%
x_train.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'restecg', 'thalach', 'exang',
#        'oldpeak', 'slope', 'ca', 'thal'],
#       dtype='object')
